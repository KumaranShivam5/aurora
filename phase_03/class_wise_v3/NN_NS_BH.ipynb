# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt

# %%
data_bh = pd.read_csv('processed_data/BH.csv')
data_bh = data_bh.sample(frac=1)
#display(data_bh)
display(data_bh.describe())
data_ns = pd.read_csv('processed_data/NS.csv')
data_ns = data_ns.sample(frac=1)
#display(data_ns)
display(data_ns.describe())


data_pulsar = pd.read_csv('processed_data/PULSAR.csv')
display(data_pulsar.describe())
data_cv = pd.read_csv('processed_data/CV.csv')
data_cv.describe()
data_cv= data_cv.sample(frac=1)
data = pd.concat([data_bh , data_ns ] , axis=0)
#display(data)
data =  data.sample(frac=1)
max_flux = 12
min_flux = 26
data = data[data['flux_aper']>max_flux]
data = data[data['flux_aper']<min_flux]
data = data[data['flux_aper_lolim']<min_flux]
data = data[data['flux_aper_hilim']>(max_flux-2)]
data = data[data['significance']>20]

display(data.describe())
data_class = data[['class']]
data_val = data.drop(columns=['index' , 'livetime' , 'gti_obs' , 'significance' , 'likelihood' , 'class'])
#display(data_val)
import missingno as msno
msno.matrix(data_val)
plt.show()
'''
rows = []
for d in data_val:
    rows.append(d)
print(rows)


from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
for r in rows:
    try:
        data_val[[r]] = imputer.fit_transform(data_val[[r]])
    except:
        print(r)
'''
data_val = data_val.replace(np.nan , 0)

for d in data_val:
    mean = np.mean(data_val[d])
    var = np.var(data_val[d])
    data_val[d] = (data_val[d]-mean)/var
    data_val[d] = data_val[d] / np.amax(data_val[d])
msno.matrix(data_val)
plt.show()
# Out:
#              index       livetime  significance     likelihood  \
# count  1100.000000    1100.000000   1100.000000    1100.000000
# mean     22.041818   50940.248364     47.953209   32843.961425
# std      22.213786   47492.166901     81.006175  112967.932302
# min       0.000000    4256.000000      1.840000      11.367330
# 25%       3.000000   17980.825000      9.200000     103.916100
# 50%      10.000000   37958.300000     17.390000     251.705800
# 75%      40.000000   69249.500000     44.060000    4017.937000
# max      73.000000  184208.000000    337.000000  462011.400000
#
#        var_inter_sigma  var_inter_prob  var_inter_index     var_max  \
# count     1.095000e+03     1095.000000      1095.000000  546.000000
# mean      1.012944e-04        0.770570         4.911416    0.871517
# std       1.430027e-04        0.223751         1.966590   20.079430
# min       6.731750e-08        0.221500         0.000000    0.000084
# 25%       5.171680e-07        0.604000         3.400000    0.000444
# 50%       5.134500e-05        0.807400         5.000000    0.002233
# 75%       8.803350e-05        0.998500         7.000000    0.005484
# max       4.811690e-04        1.000000         8.000000  469.200000
#
#           var_min    var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  546.000000  546.000000  ...        142.000000        142.000000
# mean     0.007131    0.010304  ...         12.906908         12.705068
# std      0.023738    0.061340  ...          0.841372          0.733658
# min      0.000024    0.000057  ...         10.999566         10.982967
# 25%      0.000243    0.000267  ...         12.496114         12.406270
# 50%      0.001183    0.001257  ...         13.083125         12.871781
# 75%      0.004266    0.004745  ...         13.433798         13.052468
# max      0.230371    1.325500  ...         14.608183         14.233364
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
# count    1.240000e+02      142.000000      142.000000      136.000000
# mean     8.396005e+05        4.731831      982.101089      754.218486
# std      9.348448e+06        9.576549      810.726794      576.530659
# min      1.425000e+00        1.008000        0.648700        0.083260
# 25%      2.655500e+00        1.730000       66.050000       58.615000
# 50%      4.668500e+00        2.728000     1071.000000      762.000000
# 75%      1.016500e+01        4.646000     1560.750000     1348.250000
# max      1.041000e+08       81.320000     3373.000000     1920.000000
#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count   142.000000   142.000000   142.000000   114.000000
# mean      2.137308     0.913699   749.999731   627.709211
# std      10.319842     0.433529   643.352664   400.918749
# min       0.402400     0.360300     0.100100    10.730000
# 25%       0.812675     0.693575    26.907500   393.550000
# 50%       0.892800     0.811000   791.300000   597.000000
# 75%       1.502000     1.033500  1224.750000  1029.250000
# max     123.800000     3.754000  2830.000000  1481.000000
#
# [8 rows x 66 columns]
#              index       livetime  significance     likelihood  \
# count  1268.000000    1268.000000   1268.000000   1.268000e+03
# mean     21.215300   20853.597003     83.881743            inf
# std      29.084807   23101.444868    117.400880            inf
# min       0.000000     916.000000      1.000000   9.494117e+00
# 25%       2.000000    7462.700000     17.270000   1.117242e+03
# 50%       9.000000    9636.400000     44.360000   1.542845e+04
# 75%      30.000000   26801.300000     90.710000   3.953709e+04
# max     150.000000  173023.700000    519.420000  1.797693e+308
#
#        var_inter_sigma  var_inter_prob  var_inter_index       var_max  \
# count     1.235000e+03     1235.000000      1235.000000   1028.000000
# mean      7.395187e-04        0.855801         6.468637     27.822399
# std       1.908386e-03        0.168945         1.687557    465.766260
# min       1.910500e-08        0.085000         0.000000      0.000150
# 25%       4.102500e-05        0.800000         6.400000      0.005506
# 50%       1.436754e-04        0.870250         6.400000      0.018155
# 75%       2.423574e-04        1.000000         8.000000      0.056987
# max       8.676740e-03        1.000000         8.000000  10250.004202
#
#            var_min     var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  1028.000000  1028.000000  ...        657.000000        657.000000
# mean      0.051117     0.358502  ...         12.139128         12.069728
# std       0.154987     6.091575  ...          0.664334          0.625338
# min       0.000068     0.000105  ...          9.791021          9.788346
# 25%       0.003110     0.003948  ...         11.672437         11.602408
# 50%       0.013687     0.015543  ...         12.269945         12.209363
# 75%       0.042755     0.050996  ...         12.499078         12.428058
# max       2.448138   137.204179  ...         14.538201         13.800519
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
# count      319.000000      657.000000      653.000000      596.000000
# mean       356.270855       33.044725      296.014043      259.522077
# std       5393.592765       30.757195      660.429729      560.822326
# min          0.197500        0.173200        0.035380        0.083460
# 25%          1.302000        4.405000       43.780000       31.437500
# 50%          5.539000       19.300000       67.400000       51.295000
# 75%         21.180000       60.930000      213.400000      192.200000
# max      96120.000000       99.720000     4861.000000     4430.000000
#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count   657.000000   657.000000   657.000000   274.000000
# mean      2.774100     1.077449   185.580538   328.543648
# std      19.176036     0.859778   496.567227   509.319533
# min       0.159500     0.121100     0.007671     0.000000
# 25%       0.791200     0.759100     1.182000    48.527500
# 50%       1.262000     1.112000     3.586000   105.900000
# 75%       1.448000     1.247000   118.600000   218.475000
# max     327.500000    13.540000  3227.000000  2502.000000
#
# [8 rows x 66 columns]
#            index       livetime  significance    likelihood  var_inter_sigma  \
# count  95.000000      95.000000     95.000000     95.000000     6.400000e+01
# mean    3.800000   38167.429474     34.787368  13917.093891     1.569417e-05
# std     6.295219   34566.563684     43.706247  22823.233977     2.432501e-05
# min     0.000000    3903.900000      1.840000     23.550950     3.031800e-07
# 25%     0.000000   10162.000000      5.690000    390.680900     4.354550e-07
# 50%     1.000000   24735.600000     12.860000    767.561600     1.856350e-06
# 75%     4.000000   49106.450000     34.310000   7690.349500     1.984400e-05
# max    24.000000  166935.300000    144.290000  62909.280000     8.061540e-05
#
#        var_inter_prob  var_inter_index     var_max    var_min   var_mean  ...  \
# count       64.000000        64.000000   91.000000  91.000000  91.000000  ...
# mean         0.549704         3.207812   10.811307   0.008486   0.027849  ...
# std          0.237813         1.819018  103.045688   0.014996   0.183337  ...
# min          0.099000         0.000000    0.000150   0.000068   0.000105  ...
# 25%          0.435812         2.062500    0.001266   0.000715   0.000823  ...
# 50%          0.594000         3.200000    0.003089   0.001824   0.002029  ...
# 75%          0.782800         5.000000    0.012217   0.011797   0.012088  ...
# max          0.900000         6.200000  983.002387   0.073643   1.751740  ...
#
#        flux_brems_lolim  flux_brems_hilim  brems_kt_hilim  brems_kt_lolim  \
# count         40.000000         40.000000       32.000000       40.000000
# mean          12.745523         12.679084      172.910084       15.949073
# std            0.599896          0.555087      809.731605       25.729744
# min           11.726999         11.693146        0.522700        0.409700
# 25%           12.286735         12.255141        5.523500        4.222000
# 50%           12.535139         12.505852        6.167500        5.092500
# 75%           13.355166         13.203847        7.161000        6.587500
# max           13.901702         13.773916     4544.000000       93.450000
#
#        brems_nh_hilim  brems_nh_lolim  bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  \
# count       40.000000       21.000000    40.000000    40.000000    40.000000
# mean        65.215895       94.668162     1.084760     0.857302    18.581310
# std        103.320202       91.493272     1.148652     0.680336    37.163859
# min          0.733300        0.296400     0.185600     0.163100     0.104400
# 25%          2.864000       35.960000     0.588850     0.525050     0.361625
# 50%         18.955000       71.940000     0.634600     0.582650     1.045500
# 75%         98.405000      145.400000     0.866600     0.817975    17.155000
# max        519.700000      379.300000     5.770000     3.038000   182.100000
#
#        bb_nh_lolim
# count    13.000000
# mean     25.214215
# std      28.506009
# min       0.242800
# 25%       4.938000
# 50%      11.790000
# 75%      40.620000
# max      87.780000
#
# [8 rows x 66 columns]
#              index       livetime  significance     likelihood  \
# count  1083.000000    1083.000000   1083.000000   1.083000e+03
# mean     27.932595   27164.564543     78.765965            inf
# std      31.116799   30206.145443     88.076366            inf
# min       0.000000    1165.800000     20.270000   1.387479e+01
# 25%       4.000000    7630.050000     29.880000   5.361242e+03
# 50%      16.000000   18023.700000     54.890000   1.542845e+04
# 75%      44.000000   37958.300000     74.200000   2.181019e+04
# max     150.000000  184208.000000    519.420000  1.797693e+308
#
#        var_inter_sigma  var_inter_prob  var_inter_index      var_max  \
# count     1.071000e+03     1071.000000      1071.000000   905.000000
# mean      3.571451e-04        0.830899         6.246110     3.870332
# std       1.254322e-03        0.158372         1.647559    96.433975
# min       4.354550e-07        0.099000         0.000000     0.000225
# 25%       5.023940e-05        0.800000         5.800000     0.004606
# 50%       8.803350e-05        0.820400         6.400000     0.012263
# 75%       1.675000e-04        1.000000         7.600000     0.023694
# max       8.676740e-03        1.000000         8.000000  2860.018458
#
#           var_min    var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  905.000000  905.000000  ...        539.000000        539.000000
# mean     0.014455    0.043170  ...         12.565572         12.452039
# std      0.018677    0.756158  ...          0.528692          0.441057
# min      0.000142    0.000146  ...         11.472370         11.449283
# 25%      0.003240    0.003826  ...         12.249530         12.179175
# 50%      0.007645    0.009815  ...         12.458546         12.372839
# 75%      0.016610    0.018852  ...         12.873568         12.686239
# max      0.203490   22.717583  ...         14.608183         14.043543
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
# count    2.530000e+02      539.000000      535.000000      486.000000
# mean     4.115238e+05       31.278070      346.900691      260.407422
# std      6.544707e+06       31.428205      660.031491      450.969948
# min      1.975000e-01        0.173200        0.035380        0.083260
# 25%      1.425000e+00        2.555500       39.200000       28.572500
# 50%      4.214000e+00       14.120000       65.860000       49.900000
# 75%      8.420000e+00       60.730000      203.300000      179.800000
# max      1.041000e+08       95.630000     3648.000000     2417.000000
#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count   539.000000   539.000000   539.000000   204.000000
# mean      1.570780     0.965418   233.099563   368.639574
# std       5.783841     0.441573   516.579016   394.823234
# min       0.159500     0.121100     0.053330     0.250000
# 25%       0.724700     0.618250     1.086000    44.930000
# 50%       1.242000     1.050000     2.973000   135.200000
# 75%       1.464000     1.231500   117.400000   616.125000
# max     123.800000     3.754000  3039.000000  1907.000000
#
# [8 rows x 66 columns]

# %%
data[['flux_aper_hilim' , 'flux_aper_lolim' ,'flux_aper']].describe()
# Out:
#        flux_aper_hilim  flux_aper_lolim   flux_aper
# count       736.000000       736.000000  736.000000
# mean         13.092856        13.312051   13.189026
# std           0.642160         0.811423    0.693173
# min          10.060488        12.018412   12.004532
# 25%          12.568830        12.663607   12.622810
# 50%          13.145688        13.302360   13.222820
# 75%          13.528060        13.812567   13.644149
# max          15.085683        16.683139   16.230807

# %%
data_bh_clean = data[data_class['class']=='BH']
display(data_bh_clean.describe())
data_ns_clean = data[data_class['class']=='NS']
display(data_ns_clean.describe())
# Out:
#             index       livetime  significance     likelihood  \
# count  296.000000     296.000000    296.000000     296.000000
# mean    30.277027   35585.255743    111.998243   80983.747667
# std     22.178114   34660.499941     99.931797  163915.948980
# min      0.000000    4490.400000     30.640000     695.747800
# 25%      9.000000   12452.100000     44.060000    4183.798000
# 50%     28.000000   27685.900000     74.200000    8352.518000
# 75%     49.000000   45334.825000    107.910000   21810.190000
# max     73.000000  184208.000000    337.000000  462011.400000
#
#        var_inter_sigma  var_inter_prob  var_inter_index     var_max  \
# count     2.960000e+02      296.000000       296.000000  231.000000
# mean      1.185316e-04        0.787872         5.777703    2.046062
# std       1.598589e-04        0.167269         1.958934   30.870149
# min       5.324400e-07        0.358200         1.000000    0.000278
# 25%       1.049000e-05        0.604000         3.333333    0.003579
# 50%       5.134500e-05        0.750000         5.500000    0.005027
# 75%       8.803350e-05        1.000000         8.000000    0.009781
# max       4.811690e-04        1.000000         8.000000  469.200000
#
#           var_min    var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  231.000000  231.000000  ...         92.000000         92.000000
# mean     0.005824    0.012957  ...         13.099677         12.824277
# std      0.007864    0.087314  ...          0.633441          0.499371
# min      0.000191    0.000194  ...         11.807990         11.766243
# 25%      0.002665    0.002940  ...         12.834188         12.618527
# 50%      0.004105    0.004499  ...         13.079164         12.867580
# 75%      0.005389    0.007149  ...         13.441417         13.001920
# max      0.057274    1.325500  ...         14.608183         14.043543
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
# count    7.600000e+01       92.000000       92.000000       89.000000
# mean     1.369867e+06        4.017228     1194.571388      844.267239
# std      1.194107e+07        2.967096      771.645204      473.122677
# min      1.425000e+00        1.008000        0.648700        0.083260
# 25%      3.465250e+00        1.899000      855.275000      601.600000
# 50%      6.157500e+00        2.931000     1138.500000      851.700000
# 75%      1.369250e+01        5.111000     1668.500000     1256.000000
# max      1.041000e+08       14.810000     3373.000000     1920.000000
#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count    92.000000    92.000000    92.000000    83.000000
# mean      2.814324     0.996446   911.157945   610.383373
# std      12.785681     0.420172   616.630309   321.649001
# min       0.402400     0.360300     0.100100    15.220000
# 25%       0.867675     0.747350   625.200000   423.450000
# 50%       1.229000     0.927850   842.250000   574.800000
# 75%       1.688250     1.173750  1290.000000   837.400000
# max     123.800000     3.754000  2830.000000  1481.000000
#
# [8 rows x 66 columns]
#             index       livetime  significance     likelihood  \
# count  440.000000     440.000000    440.000000   4.400000e+02
# mean    32.113636   23533.974318     96.858886            inf
# std     40.864416   26498.919195     96.187329            inf
# min      0.000000    1165.800000     31.120000   1.387479e+01
# 25%      3.000000    7567.725000     54.890000   1.891644e+04
# 50%     12.000000   13784.800000     54.890000   1.891644e+04
# 75%     47.000000   28665.075000     90.710000   4.670549e+04
# max    150.000000  173023.700000    519.420000  1.797693e+308
#
#        var_inter_sigma  var_inter_prob  var_inter_index      var_max  \
# count       432.000000      432.000000       432.000000   404.000000
# mean          0.000702        0.877567         6.733025     7.458977
# std           0.001917        0.120265         1.204611   142.449493
# min           0.000001        0.445000         1.800000     0.000225
# 25%           0.000069        0.800000         6.400000     0.007380
# 50%           0.000144        0.876800         6.400000     0.016135
# 75%           0.000168        1.000000         8.000000     0.039544
# max           0.008677        1.000000         8.000000  2860.018458
#
#           var_min    var_mean  ...  flux_brems_lolim  flux_brems_hilim  \
# count  404.000000  404.000000  ...        269.000000        269.000000
# mean     0.022050    0.080742  ...         12.357094         12.285500
# std      0.024358    1.129419  ...          0.403073          0.347874
# min      0.000142    0.000146  ...         11.472370         11.449283
# 25%      0.004392    0.005211  ...         12.076911         12.052664
# 50%      0.013250    0.013866  ...         12.352911         12.295849
# 75%      0.033326    0.037694  ...         12.534320         12.477034
# max      0.203490   22.717583  ...         14.538201         13.666150
#
#        brems_kt_hilim  brems_kt_lolim  brems_nh_hilim  brems_nh_lolim  \
# count      122.000000      269.000000      265.000000      220.000000
# mean        44.748961       35.655003      218.299932      176.556187
# std        190.786089       33.749600      594.272916      416.514569
# min          0.197500        0.173200        0.035380        0.083460
# 25%          1.000300        4.114000       12.650000       29.425000
# 50%          5.384500       19.960000       58.230000       48.000000
# 75%          7.734000       69.330000       87.470000       70.667500
# max       1783.000000       95.630000     3648.000000     2417.000000
#
#        bb_kt_hilim  bb_kt_lolim  bb_nh_hilim  bb_nh_lolim
# count   269.000000   269.000000   269.000000    71.000000
# mean      1.424480     0.956457   125.915960   269.894690
# std       3.286726     0.487850   452.854879   435.569927
# min       0.159500     0.121100     0.053330     0.250000
# 25%       0.604700     0.561100     0.552800    17.440000
# 50%       1.223000     1.050000     1.777000    85.540000
# 75%       1.495000     1.311000    19.310000   215.550000
# max      48.290000     3.668000  3039.000000  1907.000000
#
# [8 rows x 66 columns]

# %%
def split_data(x,y,frac):
    split_no = int(len(y)*frac )
    x_train = x[:split_no]
    x_test = x[split_no:]
    y_train = y[:split_no]
    y_test = y[split_no:]
    return (x_train , y_train) , (x_test , y_test)

x = data_val.to_numpy()
y = data_class.to_numpy()
(x_train , y_train) , (x_test , y_test) =  split_data(x, y, 0.9)
print(x_train.shape , y_train.shape)
print(x_test.shape , y_test.shape)
# Out:
# (662, 62) (662, 1)
# (74, 62) (74, 1)

# %% [markdown]
# # Neural Network

# %%
def class_to_int(label , cl):
    temp = []
    for i in range(len(label)):
        #print(label[i])
        for j in range(len(cl)):
            if(label[i]==cl[j]):
                temp.append(j) 
    return temp
classes = ['BH' ,'NS' ]
y_train_int = class_to_int(y_train, classes)
y_test_int = class_to_int(y_test, classes)
one_hot_y_train =  to_categorical(y_train_int)
one_hot_y_test =  to_categorical(y_test_int)
#for y_i , y_j in zip(y_train , one_hot_y_train):
##    print(y_i , y_j)

# %%
def model_gen(shape , input_len):

    inputs =  keras.Input(shape=(input_len,))
    dense =  layers.Dense(32, activation='relu')
    x = dense(inputs)
    #x =  layers.BatchNormalization(axis=-1)(x)
    
    x = layers.Dense(32, activation='relu')(x)
    x = layers.Dense(32, activation='relu')(x)
    #x =  layers.BatchNormalization(axis=-1)(x)
    #x = layers.Dropout(0.3)(x)
    x = layers.Dense(16, activation='relu')(x)
    x = layers.Dense(4, activation='relu')(x)
    #x =  layers.BatchNormalization(axis=-1)(x)
    #x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(2 , activation='softmax')(x)
    model = keras.Model(inputs=inputs , outputs=outputs , name='trial_model')
    model.compile(
        loss = "categorical_crossentropy",
        optimizer = keras.optimizers.Adam(learning_rate=0.001),
        metrics = ["accuracy"],
    )
    return model
model = model_gen([32,32,16,8] , x_train.shape[1])
history = model.fit(x_train, one_hot_y_train, batch_size=128, epochs=80, validation_split=0.2)
# Out:
# Epoch 1/80
# 5/5 [==============================] - 3s 239ms/step - loss: 0.7607 - accuracy: 0.4246 - val_loss: 0.7467 - val_accuracy: 0.3383
# Epoch 2/80
# 5/5 [==============================] - 0s 71ms/step - loss: 0.6875 - accuracy: 0.4958 - val_loss: 0.6764 - val_accuracy: 0.5414
# Epoch 3/80
# 5/5 [==============================] - 0s 56ms/step - loss: 0.6178 - accuracy: 0.6499 - val_loss: 0.6169 - val_accuracy: 0.6541
# Epoch 4/80
# 5/5 [==============================] - 0s 84ms/step - loss: 0.5621 - accuracy: 0.7574 - val_loss: 0.5614 - val_accuracy: 0.7594
# Epoch 5/80
# 5/5 [==============================] - 0s 65ms/step - loss: 0.5162 - accuracy: 0.8250 - val_loss: 0.5157 - val_accuracy: 0.8120
# Epoch 6/80
# 5/5 [==============================] - 0s 54ms/step - loss: 0.4583 - accuracy: 0.8620 - val_loss: 0.4779 - val_accuracy: 0.8496
# Epoch 7/80
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4300 - accuracy: 0.8493 - val_loss: 0.4360 - val_accuracy: 0.8571
# Epoch 8/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3893 - accuracy: 0.8678 - val_loss: 0.4015 - val_accuracy: 0.8722
# Epoch 9/80
# 5/5 [==============================] - 0s 53ms/step - loss: 0.3325 - accuracy: 0.8884 - val_loss: 0.3722 - val_accuracy: 0.8797
# Epoch 10/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3259 - accuracy: 0.8867 - val_loss: 0.3530 - val_accuracy: 0.8722
# Epoch 11/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2942 - accuracy: 0.8921 - val_loss: 0.3380 - val_accuracy: 0.8722
# Epoch 12/80
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2739 - accuracy: 0.9002 - val_loss: 0.3207 - val_accuracy: 0.8797
# Epoch 13/80
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2528 - accuracy: 0.9149 - val_loss: 0.3226 - val_accuracy: 0.8647
# Epoch 14/80
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2423 - accuracy: 0.9117 - val_loss: 0.3068 - val_accuracy: 0.8647
# Epoch 15/80
# 5/5 [==============================] - 0s 61ms/step - loss: 0.2336 - accuracy: 0.9194 - val_loss: 0.2955 - val_accuracy: 0.8647
# Epoch 16/80
# 5/5 [==============================] - 0s 63ms/step - loss: 0.2363 - accuracy: 0.9200 - val_loss: 0.3024 - val_accuracy: 0.8571
# Epoch 17/80
# 5/5 [==============================] - 0s 62ms/step - loss: 0.1955 - accuracy: 0.9306 - val_loss: 0.2924 - val_accuracy: 0.8647
# Epoch 18/80
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1862 - accuracy: 0.9295 - val_loss: 0.2916 - val_accuracy: 0.8647
# Epoch 19/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1829 - accuracy: 0.9276 - val_loss: 0.2871 - val_accuracy: 0.8647
# Epoch 20/80
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2066 - accuracy: 0.9188 - val_loss: 0.2863 - val_accuracy: 0.8722
# Epoch 21/80
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1840 - accuracy: 0.9274 - val_loss: 0.2879 - val_accuracy: 0.8722
# Epoch 22/80
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1853 - accuracy: 0.9263 - val_loss: 0.2818 - val_accuracy: 0.8797
# Epoch 23/80
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1729 - accuracy: 0.9304 - val_loss: 0.2889 - val_accuracy: 0.8722
# Epoch 24/80
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1614 - accuracy: 0.9376 - val_loss: 0.2765 - val_accuracy: 0.8797
# Epoch 25/80
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1649 - accuracy: 0.9285 - val_loss: 0.2683 - val_accuracy: 0.8797
# Epoch 26/80
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1644 - accuracy: 0.9386 - val_loss: 0.2792 - val_accuracy: 0.8722
# Epoch 27/80
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1410 - accuracy: 0.9377 - val_loss: 0.2737 - val_accuracy: 0.8797
# Epoch 28/80
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1416 - accuracy: 0.9425 - val_loss: 0.2493 - val_accuracy: 0.8797
# Epoch 29/80
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1481 - accuracy: 0.9361 - val_loss: 0.2449 - val_accuracy: 0.8872
# Epoch 30/80
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1467 - accuracy: 0.9366 - val_loss: 0.2673 - val_accuracy: 0.8797
# Epoch 31/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1324 - accuracy: 0.9393 - val_loss: 0.2362 - val_accuracy: 0.8947
# Epoch 32/80
# 5/5 [==============================] - 0s 58ms/step - loss: 0.1457 - accuracy: 0.9523 - val_loss: 0.2333 - val_accuracy: 0.8872
# Epoch 33/80
# 5/5 [==============================] - 0s 73ms/step - loss: 0.1411 - accuracy: 0.9448 - val_loss: 0.2427 - val_accuracy: 0.8797
# Epoch 34/80
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1386 - accuracy: 0.9389 - val_loss: 0.2529 - val_accuracy: 0.8797
# Epoch 35/80
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1466 - accuracy: 0.9249 - val_loss: 0.2363 - val_accuracy: 0.8872
# Epoch 36/80
# 5/5 [==============================] - 0s 58ms/step - loss: 0.1353 - accuracy: 0.9537 - val_loss: 0.2366 - val_accuracy: 0.8947
# Epoch 37/80
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1173 - accuracy: 0.9530 - val_loss: 0.2433 - val_accuracy: 0.8872
# Epoch 38/80
# 5/5 [==============================] - 0s 61ms/step - loss: 0.1305 - accuracy: 0.9408 - val_loss: 0.2479 - val_accuracy: 0.9023
# Epoch 39/80
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1232 - accuracy: 0.9434 - val_loss: 0.2516 - val_accuracy: 0.8872
# Epoch 40/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1106 - accuracy: 0.9558 - val_loss: 0.2477 - val_accuracy: 0.8872
# Epoch 41/80
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1116 - accuracy: 0.9502 - val_loss: 0.2403 - val_accuracy: 0.8797
# Epoch 42/80
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1102 - accuracy: 0.9580 - val_loss: 0.2447 - val_accuracy: 0.8797
# Epoch 43/80
# 5/5 [==============================] - 0s 60ms/step - loss: 0.1056 - accuracy: 0.9582 - val_loss: 0.2616 - val_accuracy: 0.8872
# Epoch 44/80
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1041 - accuracy: 0.9530 - val_loss: 0.2330 - val_accuracy: 0.8722
# Epoch 45/80
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1037 - accuracy: 0.9600 - val_loss: 0.2297 - val_accuracy: 0.8872
# Epoch 46/80
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1019 - accuracy: 0.9607 - val_loss: 0.2524 - val_accuracy: 0.8872
# Epoch 47/80
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1011 - accuracy: 0.9561 - val_loss: 0.2394 - val_accuracy: 0.8947
# Epoch 48/80
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1000 - accuracy: 0.9533 - val_loss: 0.2229 - val_accuracy: 0.8797
# Epoch 49/80
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1055 - accuracy: 0.9577 - val_loss: 0.2387 - val_accuracy: 0.8797
# Epoch 50/80
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1000 - accuracy: 0.9716 - val_loss: 0.2739 - val_accuracy: 0.8947
# Epoch 51/80
# 5/5 [==============================] - 0s 63ms/step - loss: 0.1150 - accuracy: 0.9513 - val_loss: 0.2475 - val_accuracy: 0.8947
# Epoch 52/80
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1086 - accuracy: 0.9527 - val_loss: 0.2329 - val_accuracy: 0.8947
# Epoch 53/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0831 - accuracy: 0.9655 - val_loss: 0.2535 - val_accuracy: 0.8872
# Epoch 54/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0941 - accuracy: 0.9615 - val_loss: 0.2284 - val_accuracy: 0.8797
# Epoch 55/80
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0854 - accuracy: 0.9634 - val_loss: 0.2323 - val_accuracy: 0.9098
# Epoch 56/80
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0734 - accuracy: 0.9700 - val_loss: 0.2239 - val_accuracy: 0.9248
# Epoch 57/80
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0866 - accuracy: 0.9603 - val_loss: 0.2171 - val_accuracy: 0.9098
# Epoch 58/80
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0873 - accuracy: 0.9689 - val_loss: 0.2448 - val_accuracy: 0.8947
# Epoch 59/80
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0846 - accuracy: 0.9718 - val_loss: 0.2445 - val_accuracy: 0.8947
# Epoch 60/80
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0793 - accuracy: 0.9670 - val_loss: 0.2435 - val_accuracy: 0.8872
# Epoch 61/80
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0819 - accuracy: 0.9716 - val_loss: 0.2591 - val_accuracy: 0.8872
# Epoch 62/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0768 - accuracy: 0.9686 - val_loss: 0.2471 - val_accuracy: 0.9023
# Epoch 63/80
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0613 - accuracy: 0.9835 - val_loss: 0.2503 - val_accuracy: 0.8872
# Epoch 64/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0702 - accuracy: 0.9699 - val_loss: 0.2738 - val_accuracy: 0.8947
# Epoch 65/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0788 - accuracy: 0.9678 - val_loss: 0.2796 - val_accuracy: 0.8947
# Epoch 66/80
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0713 - accuracy: 0.9667 - val_loss: 0.2568 - val_accuracy: 0.8797
# Epoch 67/80
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0657 - accuracy: 0.9776 - val_loss: 0.2326 - val_accuracy: 0.9023
# Epoch 68/80
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0590 - accuracy: 0.9765 - val_loss: 0.2368 - val_accuracy: 0.9173
# Epoch 69/80
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0540 - accuracy: 0.9865 - val_loss: 0.2428 - val_accuracy: 0.8947
# Epoch 70/80
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0617 - accuracy: 0.9815 - val_loss: 0.2426 - val_accuracy: 0.8947
# Epoch 71/80
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0542 - accuracy: 0.9808 - val_loss: 0.2718 - val_accuracy: 0.8947
# Epoch 72/80
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0586 - accuracy: 0.9760 - val_loss: 0.2704 - val_accuracy: 0.8797
# Epoch 73/80
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0471 - accuracy: 0.9877 - val_loss: 0.2768 - val_accuracy: 0.8797
# Epoch 74/80
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0516 - accuracy: 0.9869 - val_loss: 0.2887 - val_accuracy: 0.9023
# Epoch 75/80
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0503 - accuracy: 0.9846 - val_loss: 0.2876 - val_accuracy: 0.8947
# Epoch 76/80
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0457 - accuracy: 0.9861 - val_loss: 0.2723 - val_accuracy: 0.8872
# Epoch 77/80
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0503 - accuracy: 0.9823 - val_loss: 0.2896 - val_accuracy: 0.8872
# Epoch 78/80
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0518 - accuracy: 0.9819 - val_loss: 0.2779 - val_accuracy: 0.8872
# Epoch 79/80
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0416 - accuracy: 0.9876 - val_loss: 0.2739 - val_accuracy: 0.8947
# Epoch 80/80
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0493 - accuracy: 0.9872 - val_loss: 0.2868 - val_accuracy: 0.8947

# %%
hist = history.history
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(hist['accuracy'] , label = 'accuracy' , color='k')
plt.plot(hist['val_accuracy'] , label = 'val_accuracy' , color='crimson')
plt.xlabel('No of epochs')
plt.legend()
plt.subplot(1,2,2)
plt.plot(hist['loss'] , label = 'loss' , color='k')
plt.plot(hist['val_loss'] , label='val_loss' , color='crimson')
plt.xlabel("No of Epochs")
plt.legend()
#plt.savefig('plots/NS_BH.png')
plt.show()

# %%
y_pred_prob = model.predict(x_train)
#y_pred=  [np.argmax(yi) for yi in y_pred]
y_pred = []
for yi in y_pred_prob:
    temp = [0]*len(yi)
    temp[np.argmax(yi)] = 1
    y_pred.append(temp)
y_pred =  np.asarray(y_pred)
#print(y)

# %%
print(one_hot_y_test.shape)
print(y_pred.shape)
cf = np.matmul(one_hot_y_test.T , y_pred)
print(cf)
# Out:
# (109, 2)
# (974, 2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17150/1072242643.py in <module>
#       1 print(one_hot_y_test.shape)
#       2 print(y_pred.shape)
# ----> 3 cf = np.matmul(one_hot_y_test.T , y_pred)
#       4 print(cf)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 974 is different from 109)

# %%
import seaborn as sns

# %%
y_pred_prob = model.predict(x_test)
#y_pred=  [np.argmax(yi) for yi in y_pred]
y_pred = []
for yi in y_pred_prob:
    temp = [0]*len(yi)
    temp[np.argmax(yi)] = 1
    y_pred.append(temp)
y_pred =  np.asarray(y_pred)
#print(y)
cf = np.matmul(one_hot_y_test.T , y_pred)

ax= plt.subplot()
sns.heatmap(cf, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['BH', 'NS']); ax.yaxis.set_ticklabels(['BH', 'NS']);
plt.savefig('plots/cf_ns_bh_test.jpg')

# %%
# %reload_ext autoreload

# %%
# %autoreload 2
from my_utils.score import test_func , conf_matrix
from my_utils.print_lines import *

# %%
cf = conf_matrix(model , x_train , one_hot_y_train)

ax= plt.subplot()
sns.heatmap(cf, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['BH', 'NS']); ax.yaxis.set_ticklabels(['BH', 'NS']);
#plt.savefig('plots/cf_ns_bh_test.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17150/2083713028.py in <module>
# ----> 1 cf = conf_matrix(model , x_train , one_hot_y_train)
#       2
#       3 ax= plt.subplot()
#       4 sns.heatmap(cf, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation
#       5
#
# NameError: name 'model' is not defined
